# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-Vijaykumar/Apache-Spark-Assesment/blob/main/pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 44 kB/s
# ...
#      |████████████████████████████████| 199 kB 47.3 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=37f3a7f877bcaca5c58e562402af16efca575760ed2310846eab2caccae87648
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
import pyspark 
from pyspark.sql import SparkSession
Session = SparkSession.builder.appName('SparkSession').getOrCreate

# %%
Session
# Out:
# <bound method SparkSession.Builder.getOrCreate of <pyspark.sql.session.SparkSession.Builder object at 0x7fbca1645c10>>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df1 = pd.read_csv('people.csv')
# Out:
#      <input type="file" id="files-abf0ad2b-c27a-4f5e-94fa-9b395990b610" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abf0ad2b-c27a-4f5e-94fa-9b395990b610">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving people.csv to people.csv

# %%
df1
# Out:
#     person_ID                        name      first      last      middle  \
# 0        3130             Burks, Rosella     Rosella     Burks         NaN
# 1        3297              Avila, Damien      Damien     Avila         NaN
# 2        3547               Olsen, Robin       Robin     Olsen         NaN
# 3        1538         Moises, Edgar Estes      Edgar    Moises       Estes
# 4        2941         Brian, Heath Pruitt      Heath     Brian      Pruitt
# 5        2401         Claude, Elvin Haney      Elvin    Claude       Haney
# 6        2070             Mosley, Edmund      Edmund    Mosley         NaN
# 7        2561        Derek, Antoine Mccoy    Antoine     Derek       Mccoy
# 8        1625            Hawkins, Callie      Callie   Hawkins         NaN
# 9        1307               Pate, Andrea      Andrea      Pate         NaN
# 10       2342                Austin, Liz         Liz    Austin         NaN
# ...

# %%
df1.to_parquet()
# Out:
# b'PAR1\x15\x04\x15\x80\x05\x15\xf6\x02L\x15P\x15\x04\x12\x00\x00\xc0\x02\x08:\x0c\x00\x05\x01\x00\xe1\r\x08\x04\xdb\r\x05\x0f\x08\x00\x02\x06\t\x08\x04}\x0b\t\x08\x04a\t\t\x08\x04\x16\x08\t\x08\x04\x01\n\t\x08\x00Y\r(\x04\x1b\x05\t\x10\x00&\r(\x00\xc3\r \x046\x10\t\x18\x00\xd8\rX\x000\r@\x04A\x04\t\x18\x00\x84\r`\x04\xbb\x11\t\x10\x00\xfb\r8\x00\xe4\r\x10\x00O\r \x00\xce\r8\x00U\r`\x00\xa3\rx\x00\x1f\r\x08\x00\xfa\r(\x00z\r \x00\xa9\r0\x04\xb0\x07\tX\x00\xc4\r \x00 \r\x10\x04Y\x0f\t\x18\x00z\rp\x04(\x0c\t\x10\x00\xff\r8\x00?\r \x00\x17\r\x18\x00O\rX<b\x08\x00\x00\x00\x00\x00\x00v\x0f\x00\x00\x00\x00\x00\x00\x15\x00\x15L\x15P,\x15P\x15\x04\x15\x06\x15\x06\x1c\x18\x08\xe4\x11\x00\x00\x00\x00\x00\x00\x18\x08A\x04\x00\x00\x00\x00\x00\x00\x16\x00(\x08\xe4\x11\x00\x00\x00\x00\x00\x00\x18\x08A\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00&\x94\x02\x00\x00\x00P\x01\x06\x0b@ \x0cDa\x1cH\xa2,L\xe3<P$MTe]X\xa6m\\\xe7}`(\x8edi\x9e&\xe8\x04\x1c\x15\x04\x195\x04\x00\x06\x19\x18\tperson_ID\x15\x02\x16P\x
# ...

# %%
df1.shape
# Out:
# (40, 9)
